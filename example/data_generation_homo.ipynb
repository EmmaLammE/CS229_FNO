# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/sep/haipeng/FWI/FiberFWI/toolbox/')
sys.path.append('../src/')

import numpy as np
from scipy.interpolate import interp2d
import matplotlib.pyplot as plt

from simulate import Simulate
from utils import wavelet

from plot_tools import plot_wavefield, plot_model

# %%
# Function to interpolate a 70x70 array to 128x64
def interpolate_array(input_array, nx, nz):
    if input_array.shape != (70, 70):
        raise ValueError("Input array must be of shape (70, 70)")

    # Define the original grid points
    x = np.linspace(0, 1, 70)
    y = np.linspace(0, 1, 70)
    
    # Create an interpolation function
    f = interp2d(x, y, input_array.T, kind='cubic')
    
    # Define the new grid points where you want to interpolate
    x_new = np.linspace(0, 1, nx)
    y_new = np.linspace(0, 1, nz)
    
    # Perform the interpolation
    result = f(x_new, y_new)
    
    return result.T

# %% [markdown]
# ## Load different geological models

# %% [markdown]
# ### Homogenerous models

# %%
vp_homo = []
vs_homo = []
rho_homo = []

nx = 128
nz = 32

for i in range(500):
    # generate true model by increasing vp linearly
    vp  = np.ones((nx, nz), dtype=np.float32) * (3000 + 3 * i)
    vs  = vp / 1.732
    rho = np.power(vp, 0.25) * 310

    vp_homo.append(vp)
    vs_homo.append(vs)
    rho_homo.append(rho)

vp_homo = np.array(vp_homo)
vs_homo = np.array(vs_homo)
rho_homo = np.array(rho_homo)

# %%
vp_model = vp_homo
vs_model = vs_homo
rho_model = rho_homo

# %%
vp_model.shape
# Out:
# (500, 128, 32)

# %%
# # Use plot_wavefield in Jupyter notebook
# from IPython.display import HTML

# wavefield_ani = plot_model(vp_model[::10,:,:])
# HTML(wavefield_ani.to_jshtml())

# %%
# System
path    = '/scr3/haipeng/fno-fd3domp/homo_data'
cluster = 'local'  # 'slurm'
taskNum = 1
thdNum  = 4
comprR  = 1E-4

# Model
dim = '2D'
nx, ny, nz = [128,     1,  32]
dx, dt, nt = [ 10, 0.001, 801]
fs, pml    = [True,        20]

# Source
domFreq   = 15.
srcNum    = 1
srcType   = 'vector'
amp       = 1e7
srcWvlt   = [wavelet(nt, dt, domFreq, 'Ricker') *amp] * srcNum
vectorAngle= [np.array([ 0, 90])]* srcNum
srcCoord = [np.array([640, 0, dx]) for i in range(srcNum)]

# Receiver
rcvComp = ['vx', 'vz', 'sr', 'pr']
rcvNum = nx
rcvCoord = np.zeros((rcvNum, 3))
for i in range(rcvNum):
    rcvCoord[i, :] = [dx * i, 0.0, dx * 2]
rcvCoord = [rcvCoord] * srcNum

# %%
vp_all = []
vs_all = []
rho_all = []
vx_all = []
vz_all = []

nsample = vp_model.shape[0]

for i in range(nsample):
    
    print(f"{i+1} / {nsample}")
    
    vp  = vp_model[i].reshape((nx, ny, nz))
    vs  = vs_model[i].reshape((nx, ny, nz))
    rho = rho_model[i].reshape((nx, ny, nz))

    if np.any(vp / (vs + 0.001) < np.sqrt(2)):
        vs = vp /1.732
        
    trueModel = {'vp': vp, 'vs': vs, 'rho': rho}
    
    # clean previous data
    # !rm -r /scr3/haipeng/fno-fd3domp/homo_data/data/obs/*
    
    # Simulation
    simulate = Simulate(path=path, cluster=cluster, taskNum=taskNum, thdNum=thdNum, comprR=comprR,
                      dim=dim, nx=nx, ny=ny, nz=nz, dx=dx, dt=dt, nt=nt, fs=fs, pml=pml, model=trueModel,
                      srcNum=srcNum, srcType=srcType, domFreq=domFreq, srcCoord=srcCoord, srcWvlt=srcWvlt,
                        vectorAngle = vectorAngle, rcvCoord=rcvCoord, rcvComp=rcvComp)
    
    
    # set time interval to be 2
    simulate.saveStep = 1
    
    ## run simulation
    simulate.forward(simuType='obs', saveSnap = True, snapComp = ['vx', 'vz'])

    # load vx data
    wavefields_vx = []
    for i in range(nt):
        wavefield = simulate.loadWavefield(simuType='obs', isrc = 0, isnap=i, comp = 'vx')
        wavefields_vx.append(wavefield.T)
        
    wavefields_vz = []
    for i in range(nt):
        wavefield = simulate.loadWavefield(simuType='obs', isrc = 0, isnap=i, comp = 'vz')
        wavefields_vz.append(wavefield.T)
    
    wavefields_vx = np.array(wavefields_vx)
    wavefields_vz = np.array(wavefields_vz)

    vp_all.append(vp)
    vs_all.append(vs)
    rho_all.append(rho)
    vx_all.append(wavefields_vx)
    vz_all.append(wavefields_vz)
# Out:
# 1 / 500
# rm: cannot remove '/scr3/haipeng/fno-fd3domp/homo_data/data/obs/*': No such file or directory
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3000.0 ~ 3000.0 m/s
# Forward modeling: vs = 1732.1 ~ 1732.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 2 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3003.0 ~ 3003.0 m/s
# Forward modeling: vs = 1733.8 ~ 1733.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 3 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3006.0 ~ 3006.0 m/s
# Forward modeling: vs = 1735.6 ~ 1735.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 4 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3009.0 ~ 3009.0 m/s
# Forward modeling: vs = 1737.3 ~ 1737.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 5 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3012.0 ~ 3012.0 m/s
# Forward modeling: vs = 1739.0 ~ 1739.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 6 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3015.0 ~ 3015.0 m/s
# Forward modeling: vs = 1740.8 ~ 1740.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 7 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3018.0 ~ 3018.0 m/s
# Forward modeling: vs = 1742.5 ~ 1742.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 8 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3021.0 ~ 3021.0 m/s
# Forward modeling: vs = 1744.2 ~ 1744.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 9 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3024.0 ~ 3024.0 m/s
# Forward modeling: vs = 1746.0 ~ 1746.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 10 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3027.0 ~ 3027.0 m/s
# Forward modeling: vs = 1747.7 ~ 1747.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 11 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3030.0 ~ 3030.0 m/s
# Forward modeling: vs = 1749.4 ~ 1749.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 12 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3033.0 ~ 3033.0 m/s
# Forward modeling: vs = 1751.2 ~ 1751.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 13 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3036.0 ~ 3036.0 m/s
# Forward modeling: vs = 1752.9 ~ 1752.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 14 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3039.0 ~ 3039.0 m/s
# Forward modeling: vs = 1754.6 ~ 1754.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 15 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3042.0 ~ 3042.0 m/s
# Forward modeling: vs = 1756.4 ~ 1756.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 16 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3045.0 ~ 3045.0 m/s
# Forward modeling: vs = 1758.1 ~ 1758.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 17 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3048.0 ~ 3048.0 m/s
# Forward modeling: vs = 1759.8 ~ 1759.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 18 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3051.0 ~ 3051.0 m/s
# Forward modeling: vs = 1761.5 ~ 1761.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 19 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3054.0 ~ 3054.0 m/s
# Forward modeling: vs = 1763.3 ~ 1763.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 20 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3057.0 ~ 3057.0 m/s
# Forward modeling: vs = 1765.0 ~ 1765.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 21 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3060.0 ~ 3060.0 m/s
# Forward modeling: vs = 1766.7 ~ 1766.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 22 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3063.0 ~ 3063.0 m/s
# Forward modeling: vs = 1768.5 ~ 1768.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 23 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3066.0 ~ 3066.0 m/s
# Forward modeling: vs = 1770.2 ~ 1770.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 24 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3069.0 ~ 3069.0 m/s
# Forward modeling: vs = 1771.9 ~ 1771.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 25 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3072.0 ~ 3072.0 m/s
# Forward modeling: vs = 1773.7 ~ 1773.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 26 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3075.0 ~ 3075.0 m/s
# Forward modeling: vs = 1775.4 ~ 1775.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 27 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3078.0 ~ 3078.0 m/s
# Forward modeling: vs = 1777.1 ~ 1777.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 28 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3081.0 ~ 3081.0 m/s
# Forward modeling: vs = 1778.9 ~ 1778.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 29 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3084.0 ~ 3084.0 m/s
# Forward modeling: vs = 1780.6 ~ 1780.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 30 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3087.0 ~ 3087.0 m/s
# Forward modeling: vs = 1782.3 ~ 1782.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 31 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3090.0 ~ 3090.0 m/s
# Forward modeling: vs = 1784.1 ~ 1784.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 32 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3093.0 ~ 3093.0 m/s
# Forward modeling: vs = 1785.8 ~ 1785.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 33 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3096.0 ~ 3096.0 m/s
# Forward modeling: vs = 1787.5 ~ 1787.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 34 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3099.0 ~ 3099.0 m/s
# Forward modeling: vs = 1789.3 ~ 1789.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 35 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3102.0 ~ 3102.0 m/s
# Forward modeling: vs = 1791.0 ~ 1791.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 36 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3105.0 ~ 3105.0 m/s
# Forward modeling: vs = 1792.7 ~ 1792.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 37 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3108.0 ~ 3108.0 m/s
# Forward modeling: vs = 1794.5 ~ 1794.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 38 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3111.0 ~ 3111.0 m/s
# Forward modeling: vs = 1796.2 ~ 1796.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 39 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3114.0 ~ 3114.0 m/s
# Forward modeling: vs = 1797.9 ~ 1797.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 40 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3117.0 ~ 3117.0 m/s
# Forward modeling: vs = 1799.7 ~ 1799.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 41 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3120.0 ~ 3120.0 m/s
# Forward modeling: vs = 1801.4 ~ 1801.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 42 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3123.0 ~ 3123.0 m/s
# Forward modeling: vs = 1803.1 ~ 1803.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 43 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3126.0 ~ 3126.0 m/s
# Forward modeling: vs = 1804.8 ~ 1804.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 44 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3129.0 ~ 3129.0 m/s
# Forward modeling: vs = 1806.6 ~ 1806.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 45 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3132.0 ~ 3132.0 m/s
# Forward modeling: vs = 1808.3 ~ 1808.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 46 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3135.0 ~ 3135.0 m/s
# Forward modeling: vs = 1810.0 ~ 1810.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 47 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3138.0 ~ 3138.0 m/s
# Forward modeling: vs = 1811.8 ~ 1811.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 48 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3141.0 ~ 3141.0 m/s
# Forward modeling: vs = 1813.5 ~ 1813.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 49 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3144.0 ~ 3144.0 m/s
# Forward modeling: vs = 1815.2 ~ 1815.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 50 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3147.0 ~ 3147.0 m/s
# Forward modeling: vs = 1817.0 ~ 1817.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 51 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3150.0 ~ 3150.0 m/s
# Forward modeling: vs = 1818.7 ~ 1818.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 52 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3153.0 ~ 3153.0 m/s
# Forward modeling: vs = 1820.4 ~ 1820.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 53 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3156.0 ~ 3156.0 m/s
# Forward modeling: vs = 1822.2 ~ 1822.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 54 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3159.0 ~ 3159.0 m/s
# Forward modeling: vs = 1823.9 ~ 1823.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 55 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3162.0 ~ 3162.0 m/s
# Forward modeling: vs = 1825.6 ~ 1825.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 56 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3165.0 ~ 3165.0 m/s
# Forward modeling: vs = 1827.4 ~ 1827.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 57 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3168.0 ~ 3168.0 m/s
# Forward modeling: vs = 1829.1 ~ 1829.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 58 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3171.0 ~ 3171.0 m/s
# Forward modeling: vs = 1830.8 ~ 1830.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 59 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3174.0 ~ 3174.0 m/s
# Forward modeling: vs = 1832.6 ~ 1832.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 60 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3177.0 ~ 3177.0 m/s
# Forward modeling: vs = 1834.3 ~ 1834.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 61 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3180.0 ~ 3180.0 m/s
# Forward modeling: vs = 1836.0 ~ 1836.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 62 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3183.0 ~ 3183.0 m/s
# Forward modeling: vs = 1837.8 ~ 1837.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 63 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3186.0 ~ 3186.0 m/s
# Forward modeling: vs = 1839.5 ~ 1839.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 64 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3189.0 ~ 3189.0 m/s
# Forward modeling: vs = 1841.2 ~ 1841.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 65 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3192.0 ~ 3192.0 m/s
# Forward modeling: vs = 1843.0 ~ 1843.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 66 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3195.0 ~ 3195.0 m/s
# Forward modeling: vs = 1844.7 ~ 1844.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 67 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3198.0 ~ 3198.0 m/s
# Forward modeling: vs = 1846.4 ~ 1846.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 68 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3201.0 ~ 3201.0 m/s
# Forward modeling: vs = 1848.2 ~ 1848.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 69 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3204.0 ~ 3204.0 m/s
# Forward modeling: vs = 1849.9 ~ 1849.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 70 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3207.0 ~ 3207.0 m/s
# Forward modeling: vs = 1851.6 ~ 1851.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 71 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3210.0 ~ 3210.0 m/s
# Forward modeling: vs = 1853.3 ~ 1853.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 72 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3213.0 ~ 3213.0 m/s
# Forward modeling: vs = 1855.1 ~ 1855.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 73 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3216.0 ~ 3216.0 m/s
# Forward modeling: vs = 1856.8 ~ 1856.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 74 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3219.0 ~ 3219.0 m/s
# Forward modeling: vs = 1858.5 ~ 1858.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 75 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3222.0 ~ 3222.0 m/s
# Forward modeling: vs = 1860.3 ~ 1860.3 m/s
# Forward modeling: Sources number = 1, vector
# ...
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4425.0 ~ 4425.0 m/s
# Forward modeling: vs = 2554.8 ~ 2554.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 477 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4428.0 ~ 4428.0 m/s
# Forward modeling: vs = 2556.6 ~ 2556.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 478 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4431.0 ~ 4431.0 m/s
# Forward modeling: vs = 2558.3 ~ 2558.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 479 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4434.0 ~ 4434.0 m/s
# Forward modeling: vs = 2560.0 ~ 2560.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 480 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4437.0 ~ 4437.0 m/s
# Forward modeling: vs = 2561.8 ~ 2561.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 481 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4440.0 ~ 4440.0 m/s
# Forward modeling: vs = 2563.5 ~ 2563.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 482 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4443.0 ~ 4443.0 m/s
# Forward modeling: vs = 2565.2 ~ 2565.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 483 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4446.0 ~ 4446.0 m/s
# Forward modeling: vs = 2567.0 ~ 2567.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 484 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4449.0 ~ 4449.0 m/s
# Forward modeling: vs = 2568.7 ~ 2568.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 485 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4452.0 ~ 4452.0 m/s
# Forward modeling: vs = 2570.4 ~ 2570.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 486 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4455.0 ~ 4455.0 m/s
# Forward modeling: vs = 2572.2 ~ 2572.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 487 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4458.0 ~ 4458.0 m/s
# Forward modeling: vs = 2573.9 ~ 2573.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 488 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4461.0 ~ 4461.0 m/s
# Forward modeling: vs = 2575.6 ~ 2575.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 489 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4464.0 ~ 4464.0 m/s
# Forward modeling: vs = 2577.4 ~ 2577.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 490 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4467.0 ~ 4467.0 m/s
# Forward modeling: vs = 2579.1 ~ 2579.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 491 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4470.0 ~ 4470.0 m/s
# Forward modeling: vs = 2580.8 ~ 2580.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 492 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4473.0 ~ 4473.0 m/s
# Forward modeling: vs = 2582.6 ~ 2582.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 493 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4476.0 ~ 4476.0 m/s
# Forward modeling: vs = 2584.3 ~ 2584.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 494 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4479.0 ~ 4479.0 m/s
# Forward modeling: vs = 2586.0 ~ 2586.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 495 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4482.0 ~ 4482.0 m/s
# Forward modeling: vs = 2587.8 ~ 2587.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 496 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4485.0 ~ 4485.0 m/s
# Forward modeling: vs = 2589.5 ~ 2589.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 497 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4488.0 ~ 4488.0 m/s
# Forward modeling: vs = 2591.2 ~ 2591.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 498 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4491.0 ~ 4491.0 m/s
# Forward modeling: vs = 2593.0 ~ 2593.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 499 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4494.0 ~ 4494.0 m/s
# Forward modeling: vs = 2594.7 ~ 2594.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source
#
# 500 / 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 4497.0 ~ 4497.0 m/s
# Forward modeling: vs = 2596.4 ~ 2596.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 4 thread(s) per source

# %%
# convert to numpy arrays
vp_all = np.array(np.squeeze(vp_all))
vs_all = np.array(np.squeeze(vs_all))
rho_all = np.array(np.squeeze(rho_all))
vx_all = np.array(vx_all)
vz_all = np.array(vz_all)

# %%
print(vp_all.shape)
print(vs_all.shape)
print(rho_all.shape)
print(vx_all.shape)
print(vz_all.shape)
# Out:
# (500, 128, 32)
# (500, 128, 32)
# (500, 128, 32)
# (500, 801, 128, 32)
# (500, 801, 128, 32)

# %%
ns, nt, nx, nz = vx_all.shape
print(ns, nt, nx, nz)
# Out:
# 500 801 128 32

# %%
np.save(f'/scr2/haipeng/openfwi_dataset_train/vp_homo_ns{ns}_nx{nx}_nz{nz}.npy', vp_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vs_homo_ns{ns}_nx{nx}_nz{nz}.npy', vs_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/rho_homo_ns{ns}_nx{nx}_nz{nz}.npy', rho_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vx_homo_ns{ns}_nt{nt}_nx{nx}_nz{nz}.npy', vx_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vz_homo_ns{ns}_nt{nt}_nx{nx}_nz{nz}.npy', vz_all)

# %%
print(f'/scr2/haipeng/openfwi_dataset_train/vp_homo_ns{ns}_nx{nx}_nz{nz}.npy')
# Out:
# /scr2/haipeng/openfwi_dataset_train/vp_homo_ns500_nx128_nz32.npy

# %%
# Use plot_wavefield in Jupyter notebook
from IPython.display import HTML

wavefield_ani = plot_wavefield(vx_all[0,::10,:,:])
HTML(wavefield_ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7127a783689646e1a903c4d5736971fd">
#   <div class="anim-controls">
#     <input id="_anim_slider7127a783689646e1a903c4d5736971fd" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7127a783689646e1a903c4d5736971fd.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim7127a783689646e1a903c4d5736971fd.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim7127a783689646e1a903c4d5736971fd.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim7127a783689646e1a903c4d5736971fd.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim7127a783689646e1a903c4d5736971fd.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim7127a783689646e1a903c4d5736971fd.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim7127a783689646e1a903c4d5736971fd.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim7127a783689646e1a903c4d5736971fd.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim7127a783689646e1a903c4d5736971fd.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim7127a783689646e1a903c4d5736971fd.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select7127a783689646e1a903c4d5736971fd"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7127a783689646e1a903c4d5736971fd"
#              >
#       <label for="_anim_radio1_7127a783689646e1a903c4d5736971fd">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7127a783689646e1a903c4d5736971fd"
#              checked>
#       <label for="_anim_radio2_7127a783689646e1a903c4d5736971fd">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7127a783689646e1a903c4d5736971fd"
#              >
#       <label for="_anim_radio3_7127a783689646e1a903c4d5736971fd">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7127a783689646e1a903c4d5736971fd";
#     var slider_id = "_anim_slider7127a783689646e1a903c4d5736971fd";
#     var loop_select_id = "_anim_loop_select7127a783689646e1a903c4d5736971fd";
#     var frames = new Array(81);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAa0ElEQ
