# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/sep/haipeng/FWI/FiberFWI/toolbox/')
sys.path.append('../src/')

import numpy as np
from scipy.interpolate import interp2d
import matplotlib.pyplot as plt

from simulate import Simulate
from utils import wavelet

from plot_tools import plot_wavefield, plot_model

# %%
# Function to interpolate a 70x70 array to 128x64
def interpolate_array(input_array, nx, nz):
    if input_array.shape != (70, 70):
        raise ValueError("Input array must be of shape (70, 70)")

    # Define the original grid points
    x = np.linspace(0, 1, 70)
    y = np.linspace(0, 1, 70)
    
    # Create an interpolation function
    f = interp2d(x, y, input_array.T, kind='cubic')
    
    # Define the new grid points where you want to interpolate
    x_new = np.linspace(0, 1, nx)
    y_new = np.linspace(0, 1, nz)
    
    # Perform the interpolation
    result = f(x_new, y_new)
    
    return result.T

# %% [markdown]
# ## Load different geological models

# %% [markdown]
# ### Homogenerous models

# %%
vp_homo = []
vs_homo = []
rho_homo = []

nx = 128
nz = 32

for i in range(200):
    # generate true model by increasing vp linearly
    vp  = np.ones((nx, nz), dtype=np.float32) * (3000 + 5 * i)
    vs  = vp / 1.732
    rho = np.power(vp, 0.25) * 310

    vp_homo.append(vp)
    vs_homo.append(vs)
    rho_homo.append(rho)

vp_homo = np.array(vp_homo)
vs_homo = np.array(vs_homo)
rho_homo = np.array(rho_homo)

# %%
# vp_flat = []
# vs_flat = []
# rho_flat = []

# nx = 256
# nz = 32

# for i in range(50):

#     # load models
#     indx = np.arange(4) * 5
    
#     dataset_vp = np.load(f'/scr2/haipeng/openfwi_dataset/model_flat_layers/vp_{i+1}.npy')[indx,0,:,:].transpose(0, 2, 1)
#     dataset_vs = np.load(f'/scr2/haipeng/openfwi_dataset/model_flat_layers/vs_{i+1}.npy')[indx,0,:,:].transpose(0, 2, 1)
#     dataset_rho = np.power(dataset_vp, 0.25) * 310

#     for j in range(dataset_vp.shape[0]):
#         vp = interpolate_array(dataset_vp[j], nx, nz)
#         vs = interpolate_array(dataset_vs[j], nx, nz)
#         rho = np.power(vp, 0.25) * 310
#         vp_flat.append(vp)
#         vs_flat.append(vs)
#         rho_flat.append(rho)

# vp_flat = np.array(vp_flat)
# vs_flat = np.array(vs_flat)
# rho_flat = np.array(rho_flat)

# %%
vp_curved = []
vs_curved = []
rho_curved = []

nx = 128
nz = 32

for i in range(50):

    # load models
    indx = np.arange(10) * 5
    
    dataset_vp = np.load(f'/scr2/haipeng/openfwi_dataset/model_curved_layers/vp_{i+1}.npy')[indx,0,:,:].transpose(0, 2, 1)
    dataset_vs = np.load(f'/scr2/haipeng/openfwi_dataset/model_curved_layers/vs_{i+1}.npy')[indx,0,:,:].transpose(0, 2, 1)
    dataset_rho = np.power(dataset_vp, 0.25) * 310

    for j in range(dataset_vp.shape[0]):
        vp = interpolate_array(dataset_vp[j], nx, nz)
        vs = interpolate_array(dataset_vs[j], nx, nz)
        rho = np.power(vp, 0.25) * 310
        vp_curved.append(vp)
        vs_curved.append(vs)
        rho_curved.append(rho)


vp_curved = np.array(vp_curved)
vs_curved = np.array(vs_curved)
rho_curved = np.array(rho_curved)
# Out:
# /tmp/ipykernel_27214/4219248488.py:11: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://gist.github.com/ev-br/8544371b40f414b7eaf3fe6217209bff`
#
#   f = interp2d(x, y, input_array.T, kind='cubic')
# /tmp/ipykernel_27214/4219248488.py:18: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://gist.github.com/ev-br/8544371b40f414b7eaf3fe6217209bff`
#
#   result = f(x_new, y_new)

# %%
vp_model = vp_curved
vs_model = vs_curved
rho_model = rho_curved

# %%
vp_model.shape
# Out:
# (500, 128, 32)

# %%
# # Use plot_wavefield in Jupyter notebook
# from IPython.display import HTML

# wavefield_ani = plot_model(vp_model[::10,:,:])
# HTML(wavefield_ani.to_jshtml())

# %%
# System
path    = '/scr3/haipeng/fno-fd3domp/curved_data'
cluster = 'local'  # 'slurm'
taskNum = 3
thdNum  = 1
comprR  = 1E-4

# Model
dim = '2D'
nx, ny, nz = [128,     1,  32]
dx, dt, nt = [ 10, 0.001, 801]
fs, pml    = [True,        20]

# Source
domFreq   = 15.
srcNum    = 1
srcType   = 'vector'
amp       = 1e7
srcWvlt   = [wavelet(nt, dt, domFreq, 'Ricker') *amp] * srcNum
vectorAngle= [np.array([ 0, 90])]* srcNum
srcCoord = [np.array([640, 0, dx]) for i in range(srcNum)]

# Receiver
rcvComp = ['vx', 'vz', 'sr', 'pr']
rcvNum = nx
rcvCoord = np.zeros((rcvNum, 3))
for i in range(rcvNum):
    rcvCoord[i, :] = [dx * i, 0.0, dx * 2]
rcvCoord = [rcvCoord] * srcNum

# %%
dataset_vp.dtype
# Out:
# dtype('float32')

# %%
vp_all = []
vs_all = []
rho_all = []
vx_all = []
vz_all = []

nsample = vp_model.shape[0]

for i in range(nsample):
    
    print(f"{i+1}/ {nsample}")
    
    vp  = vp_model[i].reshape((nx, ny, nz))
    vs  = vs_model[i].reshape((nx, ny, nz))
    rho = rho_model[i].reshape((nx, ny, nz))

    if np.any(vp / (vs + 0.001) < np.sqrt(2)):
        vs = vp /1.732
        
    trueModel = {'vp': vp, 'vs': vs, 'rho': rho}
    
    # clean previous data
    # !rm -r /scr3/haipeng/fno-fd3domp/curved_data/data/obs/*
    
    # Simulation
    simulate = Simulate(path=path, cluster=cluster, taskNum=taskNum, thdNum=thdNum, comprR=comprR,
                      dim=dim, nx=nx, ny=ny, nz=nz, dx=dx, dt=dt, nt=nt, fs=fs, pml=pml, model=trueModel,
                      srcNum=srcNum, srcType=srcType, domFreq=domFreq, srcCoord=srcCoord, srcWvlt=srcWvlt,
                        vectorAngle = vectorAngle, rcvCoord=rcvCoord, rcvComp=rcvComp)
    
    
    # set time interval to be 2
    simulate.saveStep = 1
    
    ## run simulation
    simulate.forward(simuType='obs', saveSnap = True, snapComp = ['vx', 'vz'])

    # load vx data
    wavefields_vx = []
    for i in range(nt):
        wavefield = simulate.loadWavefield(simuType='obs', isrc = 0, isnap=i, comp = 'vx')
        wavefields_vx.append(wavefield.T)
        
    wavefields_vz = []
    for i in range(nt):
        wavefield = simulate.loadWavefield(simuType='obs', isrc = 0, isnap=i, comp = 'vz')
        wavefields_vz.append(wavefield.T)
    
    wavefields_vx = np.array(wavefields_vx)
    wavefields_vz = np.array(wavefields_vz)

    vp_all.append(vp)
    vs_all.append(vs)
    rho_all.append(rho)
    vx_all.append(wavefields_vx)
    vz_all.append(wavefields_vz)
# Out:
# 1/ 500
# rm: cannot remove '/scr3/haipeng/fno-fd3domp/curved_data/data/obs/*': No such file or directory
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1495.0 ~ 4079.4 m/s
# Forward modeling: vs = 956.9 ~ 2611.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 2/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1709.5 ~ 3805.5 m/s
# Forward modeling: vs = 984.5 ~ 2191.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 3/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1571.8 ~ 4463.8 m/s
# Forward modeling: vs = 1044.1 ~ 2965.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 4/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1640.2 ~ 4633.3 m/s
# Forward modeling: vs = 909.7 ~ 3128.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 5/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2076.5 ~ 4567.0 m/s
# Forward modeling: vs = 1162.2 ~ 2556.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 6/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1721.0 ~ 3416.4 m/s
# Forward modeling: vs = 892.6 ~ 1830.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 7/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1819.5 ~ 3586.8 m/s
# Forward modeling: vs = 1136.3 ~ 2266.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 8/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2087.5 ~ 4375.9 m/s
# Forward modeling: vs = 1088.5 ~ 2281.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 9/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1892.8 ~ 4351.4 m/s
# Forward modeling: vs = 1222.2 ~ 2809.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 10/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2066.4 ~ 4493.5 m/s
# Forward modeling: vs = 1110.4 ~ 2451.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 11/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2436.7 ~ 4320.1 m/s
# Forward modeling: vs = 1366.8 ~ 2426.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 12/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1785.9 ~ 3684.8 m/s
# Forward modeling: vs = 1007.3 ~ 2076.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 13/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1540.9 ~ 4797.2 m/s
# Forward modeling: vs = 870.7 ~ 2710.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 14/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1457.6 ~ 4425.7 m/s
# Forward modeling: vs = 894.2 ~ 2717.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 15/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2512.4 ~ 4753.2 m/s
# Forward modeling: vs = 1450.6 ~ 2744.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 16/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1743.8 ~ 4615.8 m/s
# Forward modeling: vs = 1008.9 ~ 2670.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 17/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1838.1 ~ 3729.6 m/s
# Forward modeling: vs = 1061.7 ~ 2154.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 18/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1571.9 ~ 4012.3 m/s
# Forward modeling: vs = 907.6 ~ 2316.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 19/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2129.0 ~ 4100.7 m/s
# Forward modeling: vs = 1378.9 ~ 2656.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 20/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 888.3 ~ 4441.2 m/s
# Forward modeling: vs = 429.2 ~ 2456.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 21/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2048.7 ~ 4626.6 m/s
# Forward modeling: vs = 1156.0 ~ 2610.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 22/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1441.2 ~ 3867.5 m/s
# Forward modeling: vs = 860.5 ~ 2309.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 23/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1571.5 ~ 3894.4 m/s
# Forward modeling: vs = 999.1 ~ 2476.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 24/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1734.5 ~ 4518.5 m/s
# Forward modeling: vs = 1034.2 ~ 2693.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 25/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1511.5 ~ 4268.8 m/s
# Forward modeling: vs = 943.0 ~ 2663.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 26/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1921.0 ~ 4621.6 m/s
# Forward modeling: vs = 1142.7 ~ 2903.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 27/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1794.0 ~ 4540.1 m/s
# Forward modeling: vs = 1151.8 ~ 2914.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 28/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2104.2 ~ 4187.9 m/s
# Forward modeling: vs = 1116.0 ~ 2221.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 29/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1954.4 ~ 4399.4 m/s
# Forward modeling: vs = 962.1 ~ 2166.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 30/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1817.9 ~ 4270.1 m/s
# Forward modeling: vs = 971.6 ~ 2282.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 31/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1892.4 ~ 4660.4 m/s
# Forward modeling: vs = 804.2 ~ 2217.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 32/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1595.2 ~ 4005.0 m/s
# Forward modeling: vs = 921.0 ~ 2312.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 33/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2351.4 ~ 3820.3 m/s
# Forward modeling: vs = 1042.3 ~ 1738.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 34/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1633.4 ~ 4463.1 m/s
# Forward modeling: vs = 923.5 ~ 2523.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 35/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2164.4 ~ 4673.0 m/s
# Forward modeling: vs = 1184.3 ~ 2556.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 36/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1751.1 ~ 3382.4 m/s
# Forward modeling: vs = 1142.8 ~ 2193.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 37/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1529.4 ~ 4294.8 m/s
# Forward modeling: vs = 791.0 ~ 2221.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 38/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1944.7 ~ 4530.9 m/s
# Forward modeling: vs = 1085.0 ~ 2958.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 39/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1533.4 ~ 4083.3 m/s
# Forward modeling: vs = 885.3 ~ 2357.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 40/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1453.3 ~ 4074.7 m/s
# Forward modeling: vs = 854.7 ~ 2407.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 41/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1683.1 ~ 3572.4 m/s
# Forward modeling: vs = 916.6 ~ 2062.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 42/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1501.3 ~ 4450.9 m/s
# Forward modeling: vs = 993.1 ~ 2944.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 43/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1450.4 ~ 3952.6 m/s
# Forward modeling: vs = 821.1 ~ 2237.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 44/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2069.2 ~ 4411.5 m/s
# Forward modeling: vs = 1260.3 ~ 2687.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 45/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1584.7 ~ 3506.4 m/s
# Forward modeling: vs = 916.7 ~ 2028.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 46/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1564.9 ~ 3704.0 m/s
# Forward modeling: vs = 662.6 ~ 2132.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 47/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1613.7 ~ 4165.9 m/s
# Forward modeling: vs = 972.4 ~ 2510.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 48/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3009.1 ~ 4085.0 m/s
# Forward modeling: vs = 1733.8 ~ 2565.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 49/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1749.4 ~ 4590.2 m/s
# Forward modeling: vs = 765.6 ~ 2008.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 50/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1477.9 ~ 4596.8 m/s
# Forward modeling: vs = 779.9 ~ 2425.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 51/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1475.4 ~ 4402.9 m/s
# Forward modeling: vs = 804.5 ~ 2398.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 52/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1613.2 ~ 4362.5 m/s
# Forward modeling: vs = 964.0 ~ 2874.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 53/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2002.9 ~ 4005.8 m/s
# Forward modeling: vs = 976.5 ~ 1953.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 54/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1501.7 ~ 3041.1 m/s
# Forward modeling: vs = 838.0 ~ 1804.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 55/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1461.5 ~ 4552.7 m/s
# Forward modeling: vs = 919.3 ~ 2863.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 56/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1654.4 ~ 4178.0 m/s
# Forward modeling: vs = 1016.5 ~ 2567.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 57/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2003.1 ~ 4658.9 m/s
# Forward modeling: vs = 990.7 ~ 2304.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 58/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2838.8 ~ 4264.7 m/s
# Forward modeling: vs = 1230.6 ~ 1848.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 59/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1501.3 ~ 4218.5 m/s
# Forward modeling: vs = 773.2 ~ 2734.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 60/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2519.1 ~ 4234.9 m/s
# Forward modeling: vs = 1283.8 ~ 2748.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 61/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2130.2 ~ 4496.5 m/s
# Forward modeling: vs = 1199.2 ~ 2571.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 62/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2139.5 ~ 4381.4 m/s
# Forward modeling: vs = 1212.0 ~ 2482.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 63/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1668.1 ~ 4137.0 m/s
# Forward modeling: vs = 1056.0 ~ 2619.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 64/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1547.0 ~ 4328.4 m/s
# Forward modeling: vs = 803.7 ~ 2251.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 65/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1881.7 ~ 4277.2 m/s
# Forward modeling: vs = 982.9 ~ 2234.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 66/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1603.0 ~ 4076.1 m/s
# Forward modeling: vs = 732.2 ~ 1861.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 67/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2586.8 ~ 3539.4 m/s
# Forward modeling: vs = 1499.3 ~ 2051.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 68/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1628.7 ~ 3656.8 m/s
# Forward modeling: vs = 705.2 ~ 1583.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 69/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1208.7 ~ 4452.2 m/s
# Forward modeling: vs = 772.3 ~ 2808.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 70/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2040.6 ~ 4349.0 m/s
# Forward modeling: vs = 996.2 ~ 2123.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 71/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2801.5 ~ 3518.3 m/s
# Forward modeling: vs = 1690.9 ~ 2123.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 72/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1951.2 ~ 4049.9 m/s
# Forward modeling: vs = 1017.2 ~ 2111.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 73/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1699.7 ~ 4591.8 m/s
# Forward modeling: vs = 787.7 ~ 2127.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 74/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1300.1 ~ 4241.2 m/s
# Forward modeling: vs = 863.2 ~ 2815.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 75/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2218.6 ~ 3939.0 m/s
# Forward modeling: vs = 1203.4 ~ 2147.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 76/ 500
# ...
#
# 476/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1404.1 ~ 4192.1 m/s
# Forward modeling: vs = 650.0 ~ 1940.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 477/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2837.0 ~ 3612.8 m/s
# Forward modeling: vs = 1390.6 ~ 2129.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 478/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1447.1 ~ 3194.6 m/s
# Forward modeling: vs = 861.5 ~ 1902.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 479/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1588.3 ~ 3612.6 m/s
# Forward modeling: vs = 992.7 ~ 2309.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 480/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2249.3 ~ 4609.8 m/s
# Forward modeling: vs = 1400.6 ~ 2877.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 481/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2283.8 ~ 4102.7 m/s
# Forward modeling: vs = 1155.1 ~ 2109.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 482/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1573.4 ~ 4171.5 m/s
# Forward modeling: vs = 897.3 ~ 2379.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 483/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2355.0 ~ 4286.4 m/s
# Forward modeling: vs = 1534.1 ~ 2792.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 484/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1850.5 ~ 4513.3 m/s
# Forward modeling: vs = 783.3 ~ 1910.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 485/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2448.0 ~ 3927.6 m/s
# Forward modeling: vs = 1593.6 ~ 2556.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 486/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1910.6 ~ 4364.2 m/s
# Forward modeling: vs = 1203.6 ~ 2748.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 487/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1710.2 ~ 4362.8 m/s
# Forward modeling: vs = 911.0 ~ 2324.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 488/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2321.7 ~ 4128.2 m/s
# Forward modeling: vs = 963.2 ~ 1712.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 489/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1549.1 ~ 3153.5 m/s
# Forward modeling: vs = 894.4 ~ 1820.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 490/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2268.8 ~ 4506.3 m/s
# Forward modeling: vs = 946.0 ~ 2327.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 491/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1981.4 ~ 2581.0 m/s
# Forward modeling: vs = 1009.7 ~ 1605.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 492/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1442.1 ~ 4122.9 m/s
# Forward modeling: vs = 871.2 ~ 2490.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 493/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2334.5 ~ 4274.1 m/s
# Forward modeling: vs = 1479.9 ~ 2709.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 494/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1937.9 ~ 4494.2 m/s
# Forward modeling: vs = 1165.4 ~ 2914.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 495/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1381.1 ~ 4287.5 m/s
# Forward modeling: vs = 882.5 ~ 2739.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 496/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1421.8 ~ 3592.3 m/s
# Forward modeling: vs = 775.3 ~ 1970.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 497/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2245.8 ~ 4017.4 m/s
# Forward modeling: vs = 958.7 ~ 1715.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 498/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2079.3 ~ 4615.4 m/s
# Forward modeling: vs = 1342.2 ~ 2979.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 499/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1807.1 ~ 4067.5 m/s
# Forward modeling: vs = 1098.4 ~ 2518.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 500/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1628.1 ~ 4002.7 m/s
# Forward modeling: vs = 933.0 ~ 2293.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source

# %%
# convert to numpy arrays
vp_all = np.array(np.squeeze(vp_all))
vs_all = np.array(np.squeeze(vs_all))
rho_all = np.array(np.squeeze(rho_all))
vx_all = np.array(vx_all)
vz_all = np.array(vz_all)

# %%
print(vp_all.shape)
print(vs_all.shape)
print(rho_all.shape)
print(vx_all.shape)
print(vz_all.shape)
# Out:
# (500, 128, 32)
# (500, 128, 32)
# (500, 128, 32)
# (500, 801, 128, 32)
# (500, 801, 128, 32)

# %%
ns, nt, nx, nz = vz_all.shape
print(ns, nt, nx, nz)
# Out:
# 500 801 128 32

# %%
np.save(f'/scr2/haipeng/openfwi_dataset_train/vp_curved_ns{ns}_nx{nx}_nz{nz}.npy', vp_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vs_curved_ns{ns}_nx{nx}_nz{nz}.npy', vs_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/rho_curved_ns{ns}_nx{nx}_nz{nz}.npy', rho_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vx_curved_ns{ns}_nt{nt}_nx{nx}_nz{nz}.npy', vx_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vz_curved_ns{ns}_nt{nt}_nx{nx}_nz{nz}.npy', vz_all)

# %%
# Use plot_wavefield in Jupyter notebook
from IPython.display import HTML

wavefield_ani = plot_wavefield(vz_all[10,::10,:,:])
HTML(wavefield_ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgbc8826e8c26540ee9d49287da743266e">
#   <div class="anim-controls">
#     <input id="_anim_sliderbc8826e8c26540ee9d49287da743266e" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animbc8826e8c26540ee9d49287da743266e.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animbc8826e8c26540ee9d49287da743266e.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animbc8826e8c26540ee9d49287da743266e.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animbc8826e8c26540ee9d49287da743266e.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animbc8826e8c26540ee9d49287da743266e.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animbc8826e8c26540ee9d49287da743266e.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animbc8826e8c26540ee9d49287da743266e.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animbc8826e8c26540ee9d49287da743266e.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animbc8826e8c26540ee9d49287da743266e.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animbc8826e8c26540ee9d49287da743266e.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectbc8826e8c26540ee9d49287da743266e"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_bc8826e8c26540ee9d49287da743266e"
#              >
#       <label for="_anim_radio1_bc8826e8c26540ee9d49287da743266e">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_bc8826e8c26540ee9d49287da743266e"
#              checked>
#       <label for="_anim_radio2_bc8826e8c26540ee9d49287da743266e">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_bc8826e8c26540ee9d49287da743266e"
#              >
#       <label for="_anim_radio3_bc8826e8c26540ee9d49287da743266e">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbc8826e8c26540ee9d49287da743266e";
#     var slider_id = "_anim_sliderbc8826e8c26540ee9d49287da743266e";
#     var loop_select_id = "_anim_loop_selectbc8826e8c26540ee9d49287da743266e";
#     var frames = new Array(81);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAaxElEQ
