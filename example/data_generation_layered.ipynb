# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/sep/haipeng/FWI/FiberFWI/toolbox/')
sys.path.append('../src/')

import numpy as np
from scipy.interpolate import interp2d
import matplotlib.pyplot as plt

from simulate import Simulate
from utils import wavelet

from plot_tools import plot_wavefield, plot_model

# %%
# Function to interpolate a 70x70 array to 128x64
def interpolate_array(input_array, nx, nz):
    if input_array.shape != (70, 70):
        raise ValueError("Input array must be of shape (70, 70)")

    # Define the original grid points
    x = np.linspace(0, 1, 70)
    y = np.linspace(0, 1, 70)
    
    # Create an interpolation function
    f = interp2d(x, y, input_array.T, kind='cubic')
    
    # Define the new grid points where you want to interpolate
    x_new = np.linspace(0, 1, nx)
    y_new = np.linspace(0, 1, nz)
    
    # Perform the interpolation
    result = f(x_new, y_new)
    
    return result.T

# %% [markdown]
# ## Load different geological models

# %% [markdown]
# ### Layered models

# %%
vp_layered = []
vs_layered = []
rho_layered = []

nx = 128
nz = 32

for i in range(50):

    # load models
    indx = np.arange(10) * 5
    
    dataset_vp = np.load(f'/scr2/haipeng/openfwi_dataset/model_flat_layers/vp_{i+1}.npy')[indx,0,:,:].transpose(0, 2, 1)
    dataset_vs = np.load(f'/scr2/haipeng/openfwi_dataset/model_flat_layers/vs_{i+1}.npy')[indx,0,:,:].transpose(0, 2, 1)
    dataset_rho = np.power(dataset_vp, 0.25) * 310

    for j in range(dataset_vp.shape[0]):
        vp = interpolate_array(dataset_vp[j], nx, nz)
        vs = interpolate_array(dataset_vs[j], nx, nz)
        rho = np.power(vp, 0.25) * 310
        vp_layered.append(vp)
        vs_layered.append(vs)
        rho_layered.append(rho)

vp_layered = np.array(vp_layered)
vs_layered = np.array(vs_layered)
rho_layered = np.array(rho_layered)
# Out:
# /tmp/ipykernel_3473/4219248488.py:11: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://gist.github.com/ev-br/8544371b40f414b7eaf3fe6217209bff`
#
#   f = interp2d(x, y, input_array.T, kind='cubic')
# /tmp/ipykernel_3473/4219248488.py:18: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.12.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://gist.github.com/ev-br/8544371b40f414b7eaf3fe6217209bff`
#
#   result = f(x_new, y_new)

# %%
vp_model = vp_layered
vs_model = vs_layered
rho_model = rho_layered

# %%
vp_model.shape
# Out:
# (500, 128, 32)

# %%
# # Use plot_wavefield in Jupyter notebook
# from IPython.display import HTML

# wavefield_ani = plot_model(vp_model[::10,:,:])
# HTML(wavefield_ani.to_jshtml())

# %%
# System
path    = '/scr3/haipeng/fno-fd3domp/layered_data'
cluster = 'local'  # 'slurm'
taskNum = 3
thdNum  = 1
comprR  = 1E-4

# Model
dim = '2D'
nx, ny, nz = [128,     1,  32]
dx, dt, nt = [ 10, 0.001, 801]
fs, pml    = [True,        20]

# Source
domFreq   = 15.
srcNum    = 1
srcType   = 'vector'
amp       = 1e7
srcWvlt   = [wavelet(nt, dt, domFreq, 'Ricker') *amp] * srcNum
vectorAngle= [np.array([ 0, 90])]* srcNum
srcCoord = [np.array([640, 0, dx]) for i in range(srcNum)]

# Receiver
rcvComp = ['vx', 'vz', 'sr', 'pr']
rcvNum = nx
rcvCoord = np.zeros((rcvNum, 3))
for i in range(rcvNum):
    rcvCoord[i, :] = [dx * i, 0.0, dx * 2]
rcvCoord = [rcvCoord] * srcNum

# %%
dataset_vp.dtype
# Out:
# dtype('float32')

# %%
vp_all = []
vs_all = []
rho_all = []
vx_all = []
vz_all = []

nsample = vp_model.shape[0]

for i in range(nsample):
    
    print(f"{i+1}/ {nsample}")
    
    vp  = vp_model[i].reshape((nx, ny, nz))
    vs  = vs_model[i].reshape((nx, ny, nz))
    rho = rho_model[i].reshape((nx, ny, nz))

    if np.any(vp / (vs + 0.001) < np.sqrt(2)):
        vs = vp /1.732
        
    trueModel = {'vp': vp, 'vs': vs, 'rho': rho}
    
    # clean previous data
    # !rm -r /scr3/haipeng/fno-fd3domp/layered_data/data/obs/*
    
    # Simulation
    simulate = Simulate(path=path, cluster=cluster, taskNum=taskNum, thdNum=thdNum, comprR=comprR,
                      dim=dim, nx=nx, ny=ny, nz=nz, dx=dx, dt=dt, nt=nt, fs=fs, pml=pml, model=trueModel,
                      srcNum=srcNum, srcType=srcType, domFreq=domFreq, srcCoord=srcCoord, srcWvlt=srcWvlt,
                        vectorAngle = vectorAngle, rcvCoord=rcvCoord, rcvComp=rcvComp)
    
    
    # set time interval to be 2
    simulate.saveStep = 1
    
    ## run simulation
    simulate.forward(simuType='obs', saveSnap = True, snapComp = ['vx', 'vz'])

    # load vx data
    wavefields_vx = []
    for i in range(nt):
        wavefield = simulate.loadWavefield(simuType='obs', isrc = 0, isnap=i, comp = 'vx')
        wavefields_vx.append(wavefield.T)
        
    wavefields_vz = []
    for i in range(nt):
        wavefield = simulate.loadWavefield(simuType='obs', isrc = 0, isnap=i, comp = 'vz')
        wavefields_vz.append(wavefield.T)
    
    wavefields_vx = np.array(wavefields_vx)
    wavefields_vz = np.array(wavefields_vz)

    vp_all.append(vp)
    vs_all.append(vs)
    rho_all.append(rho)
    vx_all.append(wavefields_vx)
    vz_all.append(wavefields_vz)
# Out:
# 1/ 500
# rm: cannot remove '/scr3/haipeng/fno-fd3domp/layered_data/data/obs/*': No such file or directory
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1450.6 ~ 4088.0 m/s
# Forward modeling: vs = 782.5 ~ 2205.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 2/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1608.0 ~ 3657.3 m/s
# Forward modeling: vs = 772.6 ~ 1757.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 3/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1997.0 ~ 4298.1 m/s
# Forward modeling: vs = 985.7 ~ 2121.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 4/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1833.3 ~ 2623.2 m/s
# Forward modeling: vs = 1098.3 ~ 1571.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 5/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1532.7 ~ 3406.0 m/s
# Forward modeling: vs = 911.6 ~ 2025.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 6/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2432.9 ~ 3416.2 m/s
# Forward modeling: vs = 1425.9 ~ 2002.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 7/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1762.0 ~ 3639.0 m/s
# Forward modeling: vs = 1118.8 ~ 2352.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 8/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2120.0 ~ 3294.4 m/s
# Forward modeling: vs = 1303.7 ~ 2025.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 9/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1955.0 ~ 3791.0 m/s
# Forward modeling: vs = 1196.4 ~ 2320.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 10/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2653.3 ~ 4293.8 m/s
# Forward modeling: vs = 1684.3 ~ 2783.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 11/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1565.0 ~ 4187.0 m/s
# Forward modeling: vs = 893.0 ~ 2389.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 12/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2143.7 ~ 4391.0 m/s
# Forward modeling: vs = 1335.0 ~ 2734.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 13/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1713.8 ~ 4396.8 m/s
# Forward modeling: vs = 943.7 ~ 2422.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 14/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1537.5 ~ 3544.0 m/s
# Forward modeling: vs = 962.6 ~ 2218.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 15/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2087.0 ~ 4221.6 m/s
# Forward modeling: vs = 1356.8 ~ 2747.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 16/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1699.6 ~ 4058.2 m/s
# Forward modeling: vs = 788.0 ~ 2076.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 17/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2081.7 ~ 4380.0 m/s
# Forward modeling: vs = 939.0 ~ 2404.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 18/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1520.0 ~ 4487.4 m/s
# Forward modeling: vs = 812.0 ~ 2397.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 19/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2101.3 ~ 4112.0 m/s
# Forward modeling: vs = 947.7 ~ 2114.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 20/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1657.0 ~ 2653.6 m/s
# Forward modeling: vs = 933.7 ~ 1735.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 21/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1973.9 ~ 2860.6 m/s
# Forward modeling: vs = 974.4 ~ 1546.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 22/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1396.2 ~ 4031.3 m/s
# Forward modeling: vs = 849.7 ~ 2453.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 23/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2247.0 ~ 4386.3 m/s
# Forward modeling: vs = 1164.3 ~ 2569.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 24/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2002.7 ~ 3967.9 m/s
# Forward modeling: vs = 897.2 ~ 1777.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 25/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1825.9 ~ 3036.0 m/s
# Forward modeling: vs = 1075.0 ~ 1787.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 26/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2056.9 ~ 3396.9 m/s
# Forward modeling: vs = 1215.4 ~ 2007.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 27/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1765.6 ~ 4368.0 m/s
# Forward modeling: vs = 1070.5 ~ 2648.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 28/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1806.0 ~ 3484.7 m/s
# Forward modeling: vs = 1087.3 ~ 2097.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 29/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1709.0 ~ 3817.3 m/s
# Forward modeling: vs = 1097.0 ~ 2450.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 30/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1955.9 ~ 4358.0 m/s
# Forward modeling: vs = 1113.3 ~ 2480.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 31/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1559.3 ~ 4186.1 m/s
# Forward modeling: vs = 714.3 ~ 2543.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 32/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2470.0 ~ 3993.0 m/s
# Forward modeling: vs = 1273.6 ~ 2641.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 33/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1524.5 ~ 4489.0 m/s
# Forward modeling: vs = 995.9 ~ 2932.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 34/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1642.0 ~ 2301.0 m/s
# Forward modeling: vs = 906.8 ~ 1270.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 35/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1654.2 ~ 4212.2 m/s
# Forward modeling: vs = 1094.4 ~ 2786.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 36/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2785.9 ~ 4464.0 m/s
# Forward modeling: vs = 1841.6 ~ 2951.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 37/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2536.2 ~ 4471.6 m/s
# Forward modeling: vs = 1551.6 ~ 2734.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 38/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1749.0 ~ 3995.0 m/s
# Forward modeling: vs = 952.6 ~ 2176.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 39/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1648.0 ~ 4410.7 m/s
# Forward modeling: vs = 768.2 ~ 2056.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 40/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1809.3 ~ 4161.0 m/s
# Forward modeling: vs = 987.6 ~ 2576.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 41/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1458.6 ~ 4408.0 m/s
# Forward modeling: vs = 887.0 ~ 2780.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 42/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1687.4 ~ 4204.2 m/s
# Forward modeling: vs = 996.0 ~ 2481.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 43/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1500.0 ~ 2950.0 m/s
# Forward modeling: vs = 996.1 ~ 1959.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 44/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2146.0 ~ 4356.0 m/s
# Forward modeling: vs = 937.2 ~ 1902.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 45/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1594.7 ~ 3835.0 m/s
# Forward modeling: vs = 1037.3 ~ 2494.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 46/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1478.2 ~ 2830.3 m/s
# Forward modeling: vs = 912.7 ~ 1733.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 47/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1561.0 ~ 3950.0 m/s
# Forward modeling: vs = 883.7 ~ 2236.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 48/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1746.0 ~ 3163.7 m/s
# Forward modeling: vs = 1082.0 ~ 1960.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 49/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1709.7 ~ 4215.0 m/s
# Forward modeling: vs = 740.4 ~ 1825.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 50/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1995.8 ~ 4475.0 m/s
# Forward modeling: vs = 1022.3 ~ 2292.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 51/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1542.0 ~ 4428.0 m/s
# Forward modeling: vs = 895.1 ~ 2570.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 52/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1584.9 ~ 4338.0 m/s
# Forward modeling: vs = 1051.5 ~ 2877.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 53/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1800.0 ~ 4260.0 m/s
# Forward modeling: vs = 1164.1 ~ 2755.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 54/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2253.0 ~ 3282.3 m/s
# Forward modeling: vs = 1313.7 ~ 2099.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 55/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1562.0 ~ 3980.8 m/s
# Forward modeling: vs = 936.6 ~ 2387.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 56/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1607.0 ~ 4006.0 m/s
# Forward modeling: vs = 989.4 ~ 2466.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 57/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1777.7 ~ 2923.5 m/s
# Forward modeling: vs = 1118.9 ~ 1840.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 58/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1962.7 ~ 2491.8 m/s
# Forward modeling: vs = 1103.8 ~ 1460.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 59/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1687.9 ~ 4299.0 m/s
# Forward modeling: vs = 897.5 ~ 2450.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 60/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1792.0 ~ 3926.0 m/s
# Forward modeling: vs = 1106.7 ~ 2424.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 61/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1602.5 ~ 2954.8 m/s
# Forward modeling: vs = 910.1 ~ 1776.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 62/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1914.0 ~ 4090.0 m/s
# Forward modeling: vs = 1238.6 ~ 2646.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 63/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1488.7 ~ 3430.0 m/s
# Forward modeling: vs = 620.5 ~ 1429.6 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 64/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1645.0 ~ 3697.0 m/s
# Forward modeling: vs = 1009.6 ~ 2268.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 65/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1741.8 ~ 3637.0 m/s
# Forward modeling: vs = 853.1 ~ 1810.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 66/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1790.7 ~ 4292.0 m/s
# Forward modeling: vs = 903.7 ~ 2507.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 67/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2055.9 ~ 3758.5 m/s
# Forward modeling: vs = 1085.3 ~ 1988.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 68/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1608.0 ~ 2595.4 m/s
# Forward modeling: vs = 1045.0 ~ 1686.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 69/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1484.1 ~ 4031.0 m/s
# Forward modeling: vs = 726.8 ~ 1974.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 70/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1681.3 ~ 2581.5 m/s
# Forward modeling: vs = 1076.0 ~ 1652.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 71/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2774.7 ~ 3642.0 m/s
# Forward modeling: vs = 1627.6 ~ 2136.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 72/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1677.0 ~ 3969.9 m/s
# Forward modeling: vs = 958.0 ~ 2594.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 73/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1629.1 ~ 3590.0 m/s
# Forward modeling: vs = 975.8 ~ 2150.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 74/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1678.9 ~ 3810.0 m/s
# Forward modeling: vs = 1095.8 ~ 2486.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 75/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2070.0 ~ 4336.0 m/s
# Forward modeling: vs = 883.2 ~ 1850.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 76/ 500
# ...
#
# 476/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2580.1 ~ 4176.0 m/s
# Forward modeling: vs = 1385.0 ~ 2241.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 477/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1533.9 ~ 3825.4 m/s
# Forward modeling: vs = 821.3 ~ 2048.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 478/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2535.0 ~ 4445.0 m/s
# Forward modeling: vs = 1673.7 ~ 2934.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 479/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1789.8 ~ 4601.4 m/s
# Forward modeling: vs = 870.3 ~ 2241.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 480/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1501.8 ~ 3332.2 m/s
# Forward modeling: vs = 986.0 ~ 2187.7 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 481/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 3542.5 ~ 4211.4 m/s
# Forward modeling: vs = 2141.1 ~ 2545.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 482/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1558.1 ~ 4382.3 m/s
# Forward modeling: vs = 996.7 ~ 2803.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 483/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1817.9 ~ 4091.0 m/s
# Forward modeling: vs = 892.3 ~ 2676.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 484/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1932.7 ~ 3297.0 m/s
# Forward modeling: vs = 878.9 ~ 1499.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 485/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1537.5 ~ 3232.0 m/s
# Forward modeling: vs = 959.1 ~ 2016.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 486/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1739.4 ~ 3854.7 m/s
# Forward modeling: vs = 917.2 ~ 2032.5 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 487/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2136.3 ~ 3112.0 m/s
# Forward modeling: vs = 1056.0 ~ 1546.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 488/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1817.5 ~ 2738.0 m/s
# Forward modeling: vs = 814.3 ~ 1399.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 489/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1820.0 ~ 4110.0 m/s
# Forward modeling: vs = 836.5 ~ 1889.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 490/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1508.4 ~ 3887.0 m/s
# Forward modeling: vs = 978.4 ~ 2521.4 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 491/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1966.0 ~ 4340.0 m/s
# Forward modeling: vs = 805.0 ~ 2106.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 492/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2424.0 ~ 4429.0 m/s
# Forward modeling: vs = 1388.1 ~ 2536.3 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 493/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1400.6 ~ 4378.0 m/s
# Forward modeling: vs = 871.9 ~ 2684.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 494/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1679.6 ~ 3119.0 m/s
# Forward modeling: vs = 783.2 ~ 1930.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 495/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2712.0 ~ 4379.0 m/s
# Forward modeling: vs = 1342.9 ~ 2576.9 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 496/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1725.0 ~ 4484.4 m/s
# Forward modeling: vs = 995.9 ~ 2589.0 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 497/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1596.1 ~ 4393.0 m/s
# Forward modeling: vs = 987.8 ~ 2718.8 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 498/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 1757.0 ~ 4082.0 m/s
# Forward modeling: vs = 1012.4 ~ 2352.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 499/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2008.3 ~ 3683.9 m/s
# Forward modeling: vs = 1331.3 ~ 2442.2 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source
#
# 500/ 500
# *****************************************************
#
#       Seismic Waveform Inversion Toolbox
#
# *****************************************************
#
# Forward modeling: 2-D Cartesian Geometry
# Forward modeling: nx = 128, nz = 32, dx = 10.0 m
# Forward modeling: x  = 0 ~ 1.27 km
# Forward modeling: z  = 0 ~ 0.31 km
# Forward modeling: nt = 801, dt = 1.00 ms, time = 0.8 s
# Forward modeling: vp = 2469.4 ~ 4056.0 m/s
# Forward modeling: vs = 1518.4 ~ 2494.1 m/s
# Forward modeling: Sources number = 1, vector
# Forward modeling: Receiver component: ['vx', 'vz', 'sr', 'pr']
# Forward modeling: Parallel: 1 task, 1 thread(s) per source

# %%
# convert to numpy arrays
vp_all = np.array(np.squeeze(vp_all))
vs_all = np.array(np.squeeze(vs_all))
rho_all = np.array(np.squeeze(rho_all))
vx_all = np.array(vx_all)
vz_all = np.array(vz_all)

# %%
print(vp_all.shape)
print(vs_all.shape)
print(rho_all.shape)
print(vx_all.shape)
print(vz_all.shape)
# Out:
# (500, 128, 32)
# (500, 128, 32)
# (500, 128, 32)
# (500, 801, 128, 32)
# (500, 801, 128, 32)

# %%
ns, nt, nx, nz = vz_all.shape
print(ns, nt, nx, nz)
# Out:
# 500 801 128 32

# %%
np.save(f'/scr2/haipeng/openfwi_dataset_train/vp_layered_ns{ns}_nx{nx}_nz{nz}.npy', vp_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vs_layered_ns{ns}_nx{nx}_nz{nz}.npy', vs_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/rho_layered_ns{ns}_nx{nx}_nz{nz}.npy', rho_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vx_layered_ns{ns}_nt{nt}_nx{nx}_nz{nz}.npy', vx_all)
np.save(f'/scr2/haipeng/openfwi_dataset_train/vz_layered_ns{ns}_nt{nt}_nx{nx}_nz{nz}.npy', vz_all)

# %%
# # Use plot_wavefield in Jupyter notebook
# from IPython.display import HTML

# wavefield_ani = plot_wavefield(vz_all[0,::10,:,:])
# HTML(wavefield_ani.to_jshtml())
